# %%
import requests
import bs4
import re
import pandas as pd

# %%
from scrap_S02_SGA import episodes_S02_SGA

df = pd.DataFrame(episodes_S02_SGA)
data = df.astype({'date de diffusion': 'string'})

data.replace('(\n)','',regex=True, inplace = True)
data.replace('( millions)','',regex=True, inplace = True)
data['audience_us'].replace('(,)','.',regex=True, inplace = True)
data['audience_fr'].replace('(,)','.',regex=True, inplace = True)
data.astype({'audience_us':'float'})
data
# Out:
#                     titre numero   date de diffusion audience_us audience_fr  \
# 0       The Siege, part 3    201
# 15 juillet 2005         2.9         2.8
# 1            The Intruder    202
# 22 juillet 2005         2.6         2.5
# 2                  Runner    203
# 29 juillet 2005         2.6         2.3
# 3                    Duet    204
# 5 août 2005         2.5         2.6
# 4               Condemned    205
# 12 août 2005         2.8         1.6
# 5                 Trinity    206
# 19 août 2005         2.5         1.9
# 6                Instinct    207
# 26 août 2005         2.9         1.3
# 7              Conversion    208
# 9 septembre 2005         2.5         1.4
# 8                  Aurora    209
# 23 septembre 2005         2.2         1.4
# 9           The Lost Boys    210
# 23 septembre 2005         2.2         1.8
# 10               The Hive    211
# 6 janvier 2006         2.6         1.8
# 11               Epiphany    212
# 13 janvier 2006         2.1         1.3
# 12          Critical Mass    213
# 20 janvier 2006         2.4         1.4
# 13   Grace Under Pressure    214
# 27 janvier 2006         2.5         1.3
# 14              The Tower    215
# 3 février 2006         2.5         1.5
# 15       The Long Goodbye    216
# 10 février 2006         2.4         1.1
# 16            Coup d'État    217
# 17 février 2006         2.0         1.0
# 17                Michael    218
# 24 février 2006         2.0         1.1
# 18                Inferno    219
# 3 mars 2006         2.4         1.0
# 19                 Allies    220
# 10 mars 2006         2.4         1.1
#
#                           scenariste    realisateur
# 0                        Martin Gero    Martin Wood
# 1      Joseph Mallozzi & Paul Mullie  Peter DeLuise
# 2                   Robert C. Cooper    Martin Wood
# 3                        Martin Gero  Peter DeLuise
# 4                        Sean Carley  Peter DeLuise
# 5                     Damian Kindler    Martin Wood
# 6   Treena Hancock & Melissa R. Byer    Andy Mikita
# 7     Robert C. Cooper & Martin Gero    Brad Turner
# 8         Brad Wright et Carl Binder    Martin Wood
# 9                        Martin Gero    Brad Turner
# 10                       Carl Binder    Martin Wood
# 11        Joe Flanigan & Brad Wright  Neil Fearnley
# 12         Brad Wright & Carl Binder    Andy Mikita
# 13                       Martin Gero    Martin Wood
# 14     Joseph Mallozzi & Paul Mullie    Andy Mikita
# 15                    Damian Kindler    Andy Mikita
# 16                       Martin Gero    Martin Wood
# 17                       Carl Binder    Martin Wood
# 18                       Carl Binder  Peter DeLuise
# 19                       Martin Gero    Andy Mikita

# %%
month_list = {
    'janvier' : 1,
    'février' : 2,
    'mars' : 3,
    'avril' : 4,
    'mai' : 5,
    'juin' : 6,
    'juillet' : 7,
    'août' : 8,
    'septembre' : 9,
    'octobre' : 10,
    'novembre' : 11,
    'décembre' : 12
}

data['day'] = data['date de diffusion'].apply(lambda x: x.split(' ')[0]).apply(lambda x: x.replace('\n', ''))
data['month'] = data['date de diffusion'].apply(lambda x: x.split(' ')[1]).map(month_list)
data['year'] = data['date de diffusion'].apply(lambda x: x.split(' ')[2])
data['date de diffusion'] = pd.to_datetime(data[['year', 'month', 'day']])
data
# Out:
#                     titre numero date de diffusion audience_us audience_fr  \
# 0       The Siege, part 3    201        2005-07-15         2.9         2.8
# 1            The Intruder    202        2005-07-22         2.6         2.5
# 2                  Runner    203        2005-07-29         2.6         2.3
# 3                    Duet    204        2005-08-05         2.5         2.6
# 4               Condemned    205        2005-08-12         2.8         1.6
# 5                 Trinity    206        2005-08-19         2.5         1.9
# 6                Instinct    207        2005-08-26         2.9         1.3
# 7              Conversion    208        2005-09-09         2.5         1.4
# 8                  Aurora    209        2005-09-23         2.2         1.4
# 9           The Lost Boys    210        2005-09-23         2.2         1.8
# 10               The Hive    211        2006-01-06         2.6         1.8
# 11               Epiphany    212        2006-01-13         2.1         1.3
# 12          Critical Mass    213        2006-01-20         2.4         1.4
# 13   Grace Under Pressure    214        2006-01-27         2.5         1.3
# 14              The Tower    215        2006-02-03         2.5         1.5
# 15       The Long Goodbye    216        2006-02-10         2.4         1.1
# 16            Coup d'État    217        2006-02-17         2.0         1.0
# 17                Michael    218        2006-02-24         2.0         1.1
# 18                Inferno    219        2006-03-03         2.4         1.0
# 19                 Allies    220        2006-03-10         2.4         1.1
#
#                           scenariste    realisateur day  month  year
# 0                        Martin Gero    Martin Wood  15      7  2005
# 1      Joseph Mallozzi & Paul Mullie  Peter DeLuise  22      7  2005
# 2                   Robert C. Cooper    Martin Wood  29      7  2005
# 3                        Martin Gero  Peter DeLuise   5      8  2005
# 4                        Sean Carley  Peter DeLuise  12      8  2005
# 5                     Damian Kindler    Martin Wood  19      8  2005
# 6   Treena Hancock & Melissa R. Byer    Andy Mikita  26      8  2005
# 7     Robert C. Cooper & Martin Gero    Brad Turner   9      9  2005
# 8         Brad Wright et Carl Binder    Martin Wood  23      9  2005
# 9                        Martin Gero    Brad Turner  23      9  2005
# 10                       Carl Binder    Martin Wood   6      1  2006
# 11        Joe Flanigan & Brad Wright  Neil Fearnley  13      1  2006
# 12         Brad Wright & Carl Binder    Andy Mikita  20      1  2006
# 13                       Martin Gero    Martin Wood  27      1  2006
# 14     Joseph Mallozzi & Paul Mullie    Andy Mikita   3      2  2006
# 15                    Damian Kindler    Andy Mikita  10      2  2006
# 16                       Martin Gero    Martin Wood  17      2  2006
# 17                       Carl Binder    Martin Wood  24      2  2006
# 18                       Carl Binder  Peter DeLuise   3      3  2006
# 19                       Martin Gero    Andy Mikita  10      3  2006
