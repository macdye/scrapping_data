# %%
import requests
import bs4
import re
import pandas as pd

# %%
from scrap_S01_SGA import episodes_S01_SGA

df = pd.DataFrame(episodes_S01_SGA)
data = df.astype({'date de diffusion': 'string'})

data.replace('(\n)','',regex=True, inplace = True)
data.replace('( millions)','',regex=True, inplace = True)
data['audience_us'].replace('(,)','.',regex=True, inplace = True)
data['audience_fr'].replace('(,)','.',regex=True, inplace = True)
data.astype({'audience_us':'float'})
data
# Out:
#                     titre numero   date de diffusion audience_us audience_fr  \
# 0          Rising, part 1    101
# 16 juillet 2004         4.2         4.4
# 1          Rising, part 2    102
# 16 juillet 2004         4.2         4.4
# 2           Hide and Seek    103
# 23 juillet 2004         3.3         3.3
# 3    Thirty Eight Minutes    104
# 30 juillet 2004         3.3         3.3
# 4               Suspicion    105
# 6 août 2004         2.9         3.1
# 5         Childhood's End    106
# 13 août 2004         2.5         3.3
# 6      Poisoning the Well    107
# 20 août 2004         2.4         3.1
# 7             Underground    108
# 27 août 2004         2.5         3.2
# 8                    Home    109
# 10 septembre 2004         2.2         3.1
# 9               The Storm    110
# 17 septembre 2004         2.5         2.7
# 10                The Eye    111
# 21 janvier 2005         2.8         3.0
# 11        The Defiant One    112
# 28 janvier 2005         3.2         2.9
# 12               Hot Zone    113
# 4 février 2005         2.9         2.8
# 13              Sanctuary    114
# 11 février 2005         2.9         2.6
# 14         Before I Sleep    115
# 18 février 2005         3.0         2.2
# 15        The Brotherhood    116
# 25 février 2005         3.0         2.1
# 16   Letters From Pegasus    117
# 4 mars 2005         2.9         2.0
# 17               The Gift    118
# 11 mars 2005         2.9         1.9
# 18      The Siege, part 1    119
# 18 mars 2005         3.2         1.9
# 19      The Siege, part 2    120
# 25 mars 2005         2.9         2.0
#
#                         scenariste        realisateur
# 0   Robert C. Cooper & Brad Wright        Martin Wood
# 1   Robert C. Cooper & Brad Wright        Martin Wood
# 2   Robert C. Cooper & Brad Wright  David Warry-Smith
# 3                      Brad Wright    Mario Azzopardi
# 4                     Kerry Glover    Mario Azzopardi
# 5                      Martin Gero      David Winning
# 6                      Mary Kaiser        Brad Turner
# 7                    Peter DeLuise        Brad Turner
# 8    Joseph Mallozzi & Paul Mullie         Holly Dale
# 9                  Jill Blotevogel        Martin Wood
# 10                     Martin Gero        Martin Wood
# 11                   Peter DeLuise      Peter DeLuise
# 12                     Martin Gero    Mario Azzopardi
# 13                   Alan Brennert         James Head
# 14                     Carl Binder        Andy Mikita
# 15                     Martin Gero        Martin Wood
# 16                     Carl Binder    Mario Azzopardi
# 17  Robert C. Cooper & Martin Gero      Peter DeLuise
# 18                     Martin Gero        Martin Wood
# 19   Joseph Mallozzi & Paul Mullie        Martin Wood

# %%
month_list = {
    'janvier' : 1,
    'février' : 2,
    'mars' : 3,
    'avril' : 4,
    'mai' : 5,
    'juin' : 6,
    'juillet' : 7,
    'août' : 8,
    'septembre' : 9,
    'octobre' : 10,
    'novembre' : 11,
    'décembre' : 12
}

data['day'] = data['date de diffusion'].apply(lambda x: x.split(' ')[0]).apply(lambda x: x.replace('\n', ''))
data['month'] = data['date de diffusion'].apply(lambda x: x.split(' ')[1]).map(month_list)
data['year'] = data['date de diffusion'].apply(lambda x: x.split(' ')[2])
data['date de diffusion'] = pd.to_datetime(data[['year', 'month', 'day']])
data
# Out:
#                     titre numero date de diffusion audience_us audience_fr  \
# 0          Rising, part 1    101        2004-07-16         4.2         4.4
# 1          Rising, part 2    102        2004-07-16         4.2         4.4
# 2           Hide and Seek    103        2004-07-23         3.3         3.3
# 3    Thirty Eight Minutes    104        2004-07-30         3.3         3.3
# 4               Suspicion    105        2004-08-06         2.9         3.1
# 5         Childhood's End    106        2004-08-13         2.5         3.3
# 6      Poisoning the Well    107        2004-08-20         2.4         3.1
# 7             Underground    108        2004-08-27         2.5         3.2
# 8                    Home    109        2004-09-10         2.2         3.1
# 9               The Storm    110        2004-09-17         2.5         2.7
# 10                The Eye    111        2005-01-21         2.8         3.0
# 11        The Defiant One    112        2005-01-28         3.2         2.9
# 12               Hot Zone    113        2005-02-04         2.9         2.8
# 13              Sanctuary    114        2005-02-11         2.9         2.6
# 14         Before I Sleep    115        2005-02-18         3.0         2.2
# 15        The Brotherhood    116        2005-02-25         3.0         2.1
# 16   Letters From Pegasus    117        2005-03-04         2.9         2.0
# 17               The Gift    118        2005-03-11         2.9         1.9
# 18      The Siege, part 1    119        2005-03-18         3.2         1.9
# 19      The Siege, part 2    120        2005-03-25         2.9         2.0
#
#                         scenariste        realisateur day  month  year
# 0   Robert C. Cooper & Brad Wright        Martin Wood  16      7  2004
# 1   Robert C. Cooper & Brad Wright        Martin Wood  16      7  2004
# 2   Robert C. Cooper & Brad Wright  David Warry-Smith  23      7  2004
# 3                      Brad Wright    Mario Azzopardi  30      7  2004
# 4                     Kerry Glover    Mario Azzopardi   6      8  2004
# 5                      Martin Gero      David Winning  13      8  2004
# 6                      Mary Kaiser        Brad Turner  20      8  2004
# 7                    Peter DeLuise        Brad Turner  27      8  2004
# 8    Joseph Mallozzi & Paul Mullie         Holly Dale  10      9  2004
# 9                  Jill Blotevogel        Martin Wood  17      9  2004
# 10                     Martin Gero        Martin Wood  21      1  2005
# 11                   Peter DeLuise      Peter DeLuise  28      1  2005
# 12                     Martin Gero    Mario Azzopardi   4      2  2005
# 13                   Alan Brennert         James Head  11      2  2005
# 14                     Carl Binder        Andy Mikita  18      2  2005
# 15                     Martin Gero        Martin Wood  25      2  2005
# 16                     Carl Binder    Mario Azzopardi   4      3  2005
# 17  Robert C. Cooper & Martin Gero      Peter DeLuise  11      3  2005
# 18                     Martin Gero        Martin Wood  18      3  2005
# 19   Joseph Mallozzi & Paul Mullie        Martin Wood  25      3  2005
